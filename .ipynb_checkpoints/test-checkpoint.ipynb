# %% [raw]
# !pip install mysql-connector-python pandas matplotlib ipython python-dotenv

# %% [raw]
# pip install dash dash-bootstrap-components

# %% [raw]
# pip install sqlalchemy mysql-connector-python

# %%
import mysql.connector
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display, clear_output
import time
from dotenv import load_dotenv
import seaborn as sns
from IPython.display import display, clear_output
import dash
import plotly.graph_objs as go
from dash import dcc, html, Input, Output, State, callback, ctx
import dash_bootstrap_components as dbc
from dash.dependencies import Input, Output
from sqlalchemy import create_engine
import traceback  # To print full error stack trace

# %% [raw]
# load_dotenv()

# %% [raw]
# # Function to create a raw MySQL connection
# def create_connection():
#     connection = mysql.connector.connect(
#         host='localhost',
#         user='root',
#         password='zipcode123',
#         database='starmerter_sim'
#
#     )
#     return connection

# %% [raw]
# # def create_connection():
# # Replace these variables with your actual database credentials
#     # username = 'root'
#     # password = 'zipcode123'
#     # host = 'localhost'
#     # database = 'starmerter_sim'
#
#     # # Use SQLAlchemy's create_engine with MySQL connector
#     # connection_string = f'mysql+mysqlconnector://{username}:{password}@{host}/{database}'
#     # engine = create_engine(connection_string)
#     # return engine
#
# # Replace with actual credentials
# connection_string = "mysql+mysqlconnector://root:zipcode123@localhost/starmeter_sim"
#
# try:
#     engine = create_engine(connection_string)
#     connection = engine.connect()
#     print("Successfully connected to the database.")
#     connection.close()  # Close the connection after testing
# except Exception as e:
#     print("Failed to connect to the database.")
#     print(e)

# %% [raw]
# username = 'root'
# password = 'zipcode123'
# host = 'localhost'
# database = 'starmerter_sim'
# connection_string = f'mysql+mysqlconnector://{username}:{password}@{host}/{database}'

# %% [markdown]
# # Run Event Sim

# %%
# Function to create a connection
def create_connection():
    """Create a connection to the MySQL database using SQLAlchemy."""
    try:
        engine = create_engine(
            "mysql+mysqlconnector://root:zipcode123@localhost/starmeter_sim"
        )
        return engine
    except Exception as e:
        print(f"Error connecting to the database: {e}")
        return None

# %%
# Function to retrieve the fan count for each celebrity with error handling
def get_fan_counts():
    try:
        engine = create_connection()
        if engine is None:
            raise ValueError("Failed to create database connection.")

        query = """
        SELECT current_favorite, COUNT(*) as fan_count 
        FROM user_dynamic_preferences 
        GROUP BY current_favorite;
        """
        with engine.connect() as connection:
            df = pd.read_sql(query, con=connection)

        if df.empty:
            print("Warning: The retrieved DataFrame is empty.")
        else:
            print("Data retrieved successfully:", df)  # Debugging output
        return df

    except Exception as e:
        print(f"Error retrieving data: {e}")
        # Returning an empty DataFrame to avoid callback failure
        return pd.DataFrame(columns=['current_favorite', 'fan_count'])

# Initialize Dash app
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Initialize layout with an empty figure and an interval component
app.layout = html.Div([
    html.H1("Real-Time Fan Count of Celebrities"),
    dcc.Graph(id='live-update-graph'),
    dcc.Interval(
        id='interval-component',
        interval=1000,  # Update interval in milliseconds (0.5 seconds)
        n_intervals=0,
        disabled=True  # Interval is initially disabled
    ),
    html.Button('Start', id='start-stop-button', n_clicks=0, className="btn btn-primary"),
])

# Initialize data storage
fan_counts_data = {celebrity: [] for celebrity in ['Sabrina Carpenter', 'Snoop Dogg', 'Tony Stark', 'LeBron James']}
time_data = []

# Callback to update the graph
@app.callback(
    Output('live-update-graph', 'figure'),
    Input('interval-component', 'n_intervals')
)
def update_graph(n):
    global time_data, fan_counts_data

    try:
        # Fetch the latest fan counts
        df = get_fan_counts()

        # Check if DataFrame is empty
        if df.empty:
            print("No data to update the graph.")
            # Create an empty figure with a message
            fig = go.Figure().update_layout(
                title='No data available',
                xaxis_title='Time (seconds)',
                yaxis_title='Number of Fans'
            )
            return fig

        # Append the current timestamp
        current_time = time.time()
        time_data.append(current_time - time_data[0] if time_data else 0)

        # Update the fan counts data
        for celebrity in fan_counts_data.keys():
            fan_count = df[df['current_favorite'] == celebrity]['fan_count'].sum() if not df[df['current_favorite'] == celebrity].empty else 0
            fan_counts_data[celebrity].append(fan_count)

        # Create traces for each celebrity
        fig = go.Figure()
        for celebrity, fan_counts in fan_counts_data.items():
            fig.add_trace(go.Scatter(
                x=time_data,
                y=fan_counts,
                mode='lines+markers',
                name=celebrity,
                marker=dict(size=5),
                text=[f'{count}' for count in fan_counts],  # Custom text for each point
                hoverinfo='text'  # Only show the custom text on hover
            ))

        # Ensure time_data has enough data points to set range
        if len(time_data) > 1:
            fig.update_layout(
                xaxis=dict(range=[max(time_data) - 100, max(time_data)]),
            )

        # Set graph layout properties
        fig.update_layout(
            xaxis_title='Time (seconds)',
            yaxis_title='Number of Fans',
            title='Real-Time Fan Count of Celebrities',
        )

        print("Graph updated successfully.")  # Debug output
        return fig

    except Exception as e:
        print(f"Error in updating graph: {e}")
        # Return an empty figure with an error message
        return go.Figure().update_layout(title="Error updating graph")

# Callback to control start/stop functionality
@app.callback(
    Output('interval-component', 'disabled'),
    Output('start-stop-button', 'children'),
    Input('start-stop-button', 'n_clicks'),
    State('interval-component', 'disabled')
)
def toggle_interval(n_clicks, is_disabled):
    # Toggle the state of the interval (start/stop updates)
    if n_clicks % 2 == 0:
        return True, 'Start'  # Disabled, show 'Start' button text
    else:
        return False, 'Stop'  # Enabled, show 'Stop' button text

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2547
# 1  Sabrina Carpenter       2513
# 2         Tony Stark       2409
# 3       LeBron James       2531
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2559
# 1  Sabrina Carpenter       2502
# 2         Tony Stark       2443
# 3       LeBron James       2496
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2546
# 1  Sabrina Carpenter       2505
# 2         Tony Stark       2452
# 3       LeBron James       2497
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2546
# 1  Sabrina Carpenter       2505
# 2         Tony Stark       2452
# 3       LeBron James       2497
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2546
# 1  Sabrina Carpenter       2505
# 2         Tony Stark       2452
# 3       LeBron James       2497
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2619
# 1  Sabrina Carpenter       2584
# 2         Tony Stark       2530
# 3       LeBron James       2267
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2594
# 1  Sabrina Carpenter       2570
# 2         Tony Stark       2537
# 3       LeBron James       2299
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2566
# 1  Sabrina Carpenter       2575
# 2         Tony Stark       2543
# 3       LeBron James       2316
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2578
# 1  Sabrina Carpenter       2565
# 2       LeBron James       2322
# 3         Tony Stark       2535
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2553
# 1  Sabrina Carpenter       2555
# 2       LeBron James       2354
# 3         Tony Stark       2538
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2542
# 1       LeBron James       2369
# 2         Snoop Dogg       2553
# 3         Tony Stark       2536
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2526
# 1       LeBron James       2379
# 2         Snoop Dogg       2561
# 3         Tony Stark       2534
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2538
# 1       LeBron James       2411
# 2         Snoop Dogg       2526
# 3         Tony Stark       2525
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2501
# 1       LeBron James       2455
# 2         Snoop Dogg       2526
# 3         Tony Stark       2518
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2509
# 1       LeBron James       2438
# 2         Snoop Dogg       2542
# 3         Tony Stark       2511
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2508
# 1       LeBron James       2461
# 2         Snoop Dogg       2530
# 3         Tony Stark       2501
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2475
# 1       LeBron James       2520
# 2         Snoop Dogg       2492
# 3         Tony Stark       2513
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2479
# 1       LeBron James       2548
# 2         Snoop Dogg       2507
# 3         Tony Stark       2466
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2485
# 1       LeBron James       2552
# 2         Tony Stark       2451
# 3         Snoop Dogg       2512
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2510
# 1       LeBron James       2539
# 2         Tony Stark       2438
# 3         Snoop Dogg       2513
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2592
# 1       LeBron James       2614
# 2         Tony Stark       2505
# 3         Snoop Dogg       2289
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2579
# 1       LeBron James       2622
# 2         Tony Stark       2478
# 3         Snoop Dogg       2321
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2549
# 1       LeBron James       2620
# 2         Tony Stark       2468
# 3         Snoop Dogg       2363
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2537
# 1       LeBron James       2619
# 2         Tony Stark       2471
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2996
# 1         Tony Stark       2585
# 2  Sabrina Carpenter       2443
# 3         Snoop Dogg       1976
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2996
# 1         Tony Stark       2585
# 2  Sabrina Carpenter       2443
# 3         Snoop Dogg       1976
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2996
# 1         Tony Stark       2585
# 2  Sabrina Carpenter       2443
# 3         Snoop Dogg       1976
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2996
# 1         Tony Stark       2585
# 2  Sabrina Carpenter       2443
# 3         Snoop Dogg       1976
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2996
# 1         Tony Stark       2585
# 2  Sabrina Carpenter       2443
# 3         Snoop Dogg       1976
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2996
# 1         Tony Stark       2585
# 2  Sabrina Carpenter       2443
# 3         Snoop Dogg       1976
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2986
# 1         Tony Stark       2580
# 2  Sabrina Carpenter       2446
# 3         Snoop Dogg       1988
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2936
# 1         Tony Stark       2577
# 2  Sabrina Carpenter       2458
# 3         Snoop Dogg       2029
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2902
# 1         Tony Stark       2563
# 2  Sabrina Carpenter       2449
# 3         Snoop Dogg       2086
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2871
# 1         Tony Stark       2553
# 2  Sabrina Carpenter       2450
# 3         Snoop Dogg       2126
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2857
# 1         Tony Stark       2567
# 2  Sabrina Carpenter       2448
# 3         Snoop Dogg       2128
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2849
# 1         Tony Stark       2545
# 2  Sabrina Carpenter       2449
# 3         Snoop Dogg       2157
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2817
# 1         Tony Stark       2562
# 2  Sabrina Carpenter       2450
# 3         Snoop Dogg       2171
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2820
# 1         Tony Stark       2560
# 2  Sabrina Carpenter       2449
# 3         Snoop Dogg       2171
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2542
# 1         Tony Stark       2639
# 2  Sabrina Carpenter       2540
# 3         Snoop Dogg       2279
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2647
# 2  Sabrina Carpenter       2531
# 3         Snoop Dogg       2275
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2515
# 1         Tony Stark       2639
# 2  Sabrina Carpenter       2544
# 3         Snoop Dogg       2302
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2524
# 1         Tony Stark       2633
# 2  Sabrina Carpenter       2535
# 3         Snoop Dogg       2308
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2521
# 1         Tony Stark       2655
# 2  Sabrina Carpenter       2502
# 3         Snoop Dogg       2322
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2512
# 1         Tony Stark       2639
# 2  Sabrina Carpenter       2510
# 3         Snoop Dogg       2339
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2506
# 1         Tony Stark       2611
# 2  Sabrina Carpenter       2510
# 3         Snoop Dogg       2373
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2516
# 1         Tony Stark       2597
# 2  Sabrina Carpenter       2503
# 3         Snoop Dogg       2384
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2503
# 1         Tony Stark       2580
# 2  Sabrina Carpenter       2519
# 3         Snoop Dogg       2398
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2487
# 1         Tony Stark       2590
# 2  Sabrina Carpenter       2526
# 3         Snoop Dogg       2397
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2480
# 1         Tony Stark       2580
# 2  Sabrina Carpenter       2544
# 3         Snoop Dogg       2396
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2480
# 1         Tony Stark       2579
# 2  Sabrina Carpenter       2540
# 3         Snoop Dogg       2401
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2497
# 1         Tony Stark       2588
# 2  Sabrina Carpenter       2507
# 3         Snoop Dogg       2408
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2736
# 1         Tony Stark       2830
# 2  Sabrina Carpenter       1786
# 3         Snoop Dogg       2648
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2735
# 1         Tony Stark       2831
# 2         Snoop Dogg       2649
# 3  Sabrina Carpenter       1785
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2731
# 1         Tony Stark       2768
# 2         Snoop Dogg       2635
# 3  Sabrina Carpenter       1866
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2712
# 1         Tony Stark       2745
# 2         Snoop Dogg       2609
# 3  Sabrina Carpenter       1934
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2701
# 1         Tony Stark       2756
# 2         Snoop Dogg       2578
# 3  Sabrina Carpenter       1965
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2698
# 1         Tony Stark       2767
# 2         Snoop Dogg       2579
# 3  Sabrina Carpenter       1956
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2692
# 1         Tony Stark       2757
# 2         Snoop Dogg       2547
# 3  Sabrina Carpenter       2004
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2679
# 1         Tony Stark       2747
# 2         Snoop Dogg       2544
# 3  Sabrina Carpenter       2030
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2679
# 1         Tony Stark       2747
# 2         Snoop Dogg       2544
# 3  Sabrina Carpenter       2030
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2646
# 1         Tony Stark       2730
# 2  Sabrina Carpenter       2090
# 3         Snoop Dogg       2534
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2639
# 1         Tony Stark       2685
# 2  Sabrina Carpenter       2117
# 3         Snoop Dogg       2559
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2607
# 1         Tony Stark       2694
# 2  Sabrina Carpenter       2128
# 3         Snoop Dogg       2571
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2397
# 1         Tony Stark       2766
# 2  Sabrina Carpenter       2183
# 3         Snoop Dogg       2654
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2397
# 1         Tony Stark       2765
# 2  Sabrina Carpenter       2207
# 3         Snoop Dogg       2631
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2411
# 1         Tony Stark       2723
# 2  Sabrina Carpenter       2234
# 3         Snoop Dogg       2632
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2634
# 1         Tony Stark       2722
# 2       LeBron James       2411
# 3  Sabrina Carpenter       2233
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2592
# 1         Tony Stark       2688
# 2       LeBron James       2442
# 3  Sabrina Carpenter       2278
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2553
# 1         Tony Stark       2668
# 2       LeBron James       2493
# 3  Sabrina Carpenter       2286
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2547
# 1         Tony Stark       2654
# 2       LeBron James       2483
# 3  Sabrina Carpenter       2316
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2554
# 1         Tony Stark       2621
# 2       LeBron James       2472
# 3  Sabrina Carpenter       2353
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2572
# 1         Tony Stark       2612
# 2       LeBron James       2462
# 3  Sabrina Carpenter       2354
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2578
# 1         Tony Stark       2567
# 2       LeBron James       2508
# 3  Sabrina Carpenter       2347
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2572
# 1         Tony Stark       2583
# 2       LeBron James       2498
# 3  Sabrina Carpenter       2347
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2547
# 1         Tony Stark       2614
# 2         Snoop Dogg       2650
# 3  Sabrina Carpenter       2189
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2613
# 1         Snoop Dogg       2166
# 2       LeBron James       2664
# 3  Sabrina Carpenter       2557
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2613
# 1         Snoop Dogg       2166
# 2       LeBron James       2664
# 3  Sabrina Carpenter       2557
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2578
# 1         Snoop Dogg       2196
# 2         Tony Stark       2610
# 3       LeBron James       2616
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Snoop Dogg       2201
# 2         Tony Stark       2596
# 3       LeBron James       2614
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2766
# 1         Snoop Dogg       2388
# 2         Tony Stark       2785
# 3       LeBron James       2061
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2830
# 1         Snoop Dogg       2454
# 2         Tony Stark       2854
# 3       LeBron James       1862
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2804
# 1         Snoop Dogg       2456
# 2         Tony Stark       2835
# 3       LeBron James       1905
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2782
# 1         Snoop Dogg       2460
# 2         Tony Stark       2848
# 3       LeBron James       1910
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       3018
# 1         Snoop Dogg       2673
# 2         Tony Stark       2166
# 3       LeBron James       2143
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       3082
# 1         Snoop Dogg       2720
# 2         Tony Stark       1997
# 3       LeBron James       2201
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       3163
# 1         Snoop Dogg       2495
# 2         Tony Stark       2080
# 3       LeBron James       2262
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       3234
# 1         Snoop Dogg       2294
# 2         Tony Stark       2145
# 3       LeBron James       2327
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       3247
# 1         Snoop Dogg       2292
# 2         Tony Stark       2131
# 3       LeBron James       2330
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       3195
# 1         Snoop Dogg       2277
# 2         Tony Stark       2189
# 3       LeBron James       2339
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       3159
# 1         Snoop Dogg       2274
# 2         Tony Stark       2225
# 3       LeBron James       2342
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       3129
# 1         Snoop Dogg       2277
# 2         Tony Stark       2227
# 3       LeBron James       2367
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       3078
# 1         Snoop Dogg       2291
# 2         Tony Stark       2259
# 3       LeBron James       2372
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       3046
# 1         Snoop Dogg       2317
# 2         Tony Stark       2265
# 3       LeBron James       2372
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2946
# 1         Snoop Dogg       2363
# 2         Tony Stark       2267
# 3       LeBron James       2424
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2928
# 1         Snoop Dogg       2381
# 2         Tony Stark       2271
# 3       LeBron James       2420
# Graph updated successfully.
# Data retrieved successfully:Data retrieved successfully:      current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
#     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
# Graph updated successfully.
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2589
# 1         Tony Stark       2486
# 2       LeBron James       2473
# 3         Snoop Dogg       2452
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2440
# 1         Snoop Dogg       2467
# 2       LeBron James       2518
# 3  Sabrina Carpenter       2575
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2451
# 1         Snoop Dogg       2475
# 2       LeBron James       2492
# 3  Sabrina Carpenter       2582
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2476
# 1         Snoop Dogg       2482
# 2       LeBron James       2472
# 3  Sabrina Carpenter       2570
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2466
# 1         Snoop Dogg       2489
# 2       LeBron James       2470
# 3  Sabrina Carpenter       2575
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2469
# 1         Snoop Dogg       2487
# 2       LeBron James       2463
# 3  Sabrina Carpenter       2581
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2496
# 1         Snoop Dogg       2519
# 2       LeBron James       2445
# 3  Sabrina Carpenter       2540
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2488
# 1         Snoop Dogg       2536
# 2       LeBron James       2454
# 3  Sabrina Carpenter       2522
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2478
# 1         Snoop Dogg       2556
# 2       LeBron James       2451
# 3  Sabrina Carpenter       2515
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2458
# 1         Snoop Dogg       2566
# 2       LeBron James       2451
# 3  Sabrina Carpenter       2525
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2098
# 1         Snoop Dogg       2689
# 2       LeBron James       2567
# 3  Sabrina Carpenter       2646
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2039
# 1         Snoop Dogg       2711
# 2       LeBron James       2588
# 3  Sabrina Carpenter       2662
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2071
# 1         Snoop Dogg       2698
# 2       LeBron James       2579
# 3  Sabrina Carpenter       2652
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2093
# 1         Snoop Dogg       2713
# 2       LeBron James       2577
# 3  Sabrina Carpenter       2617
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2092
# 1         Snoop Dogg       2713
# 2       LeBron James       2580
# 3  Sabrina Carpenter       2615
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2150
# 1         Snoop Dogg       2695
# 2       LeBron James       2565
# 3  Sabrina Carpenter       2590
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2153
# 1         Snoop Dogg       2685
# 2       LeBron James       2573
# 3  Sabrina Carpenter       2589
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2307
# 1         Snoop Dogg       2808
# 2       LeBron James       2150
# 3  Sabrina Carpenter       2735
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2387
# 1         Snoop Dogg       2858
# 2       LeBron James       1953
# 3  Sabrina Carpenter       2802
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2387
# 1         Snoop Dogg       2858
# 2       LeBron James       1953
# 3  Sabrina Carpenter       2802
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2380
# 1         Snoop Dogg       2822
# 2       LeBron James       2021
# 3  Sabrina Carpenter       2777
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2377
# 1         Snoop Dogg       2812
# 2       LeBron James       2029
# 3  Sabrina Carpenter       2782
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2483
# 1         Snoop Dogg       2937
# 2       LeBron James       1681
# 3  Sabrina Carpenter       2899
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2467
# 1         Snoop Dogg       2920
# 2       LeBron James       1725
# 3  Sabrina Carpenter       2888
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2480
# 1         Snoop Dogg       2851
# 2       LeBron James       1808
# 3  Sabrina Carpenter       2861
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2510
# 1         Snoop Dogg       2873
# 2       LeBron James       1830
# 3  Sabrina Carpenter       2787
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2602
# 1         Snoop Dogg       2983
# 2       LeBron James       1920
# 3  Sabrina Carpenter       2495
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2721
# 1         Snoop Dogg       2628
# 2       LeBron James       2043
# 3  Sabrina Carpenter       2608
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2767
# 1         Snoop Dogg       2449
# 2       LeBron James       2099
# 3  Sabrina Carpenter       2685
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2828
# 1         Snoop Dogg       2507
# 2       LeBron James       1909
# 3  Sabrina Carpenter       2756
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2492
# 1       LeBron James       1952
# 2         Tony Stark       2837
# 3  Sabrina Carpenter       2719
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2473
# 1       LeBron James       2024
# 2         Tony Stark       2796
# 3  Sabrina Carpenter       2707
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2473
# 1       LeBron James       2025
# 2         Tony Stark       2797
# 3  Sabrina Carpenter       2705
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2458
# 1       LeBron James       2089
# 2         Tony Stark       2768
# 3  Sabrina Carpenter       2685
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2445
# 1       LeBron James       2126
# 2         Tony Stark       2749
# 3  Sabrina Carpenter       2680
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2749
# 1       LeBron James       2135
# 2  Sabrina Carpenter       2662
# 3         Snoop Dogg       2454
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2758
# 1       LeBron James       2163
# 2  Sabrina Carpenter       2640
# 3         Snoop Dogg       2439
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2714
# 1       LeBron James       2213
# 2  Sabrina Carpenter       2626
# 3         Snoop Dogg       2447
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2675
# 1       LeBron James       2278
# 2  Sabrina Carpenter       2580
# 3         Snoop Dogg       2467
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2631
# 1       LeBron James       2332
# 2  Sabrina Carpenter       2583
# 3         Snoop Dogg       2454
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2593
# 1       LeBron James       2378
# 2  Sabrina Carpenter       2544
# 3         Snoop Dogg       2485
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2568
# 1       LeBron James       2398
# 2  Sabrina Carpenter       2544
# 3         Snoop Dogg       2490
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2575
# 1       LeBron James       2436
# 2  Sabrina Carpenter       2515
# 3         Snoop Dogg       2474
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2581
# 1       LeBron James       2442
# 2  Sabrina Carpenter       2506
# 3         Snoop Dogg       2471
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       1876
# 1       LeBron James       2671
# 2  Sabrina Carpenter       2760
# 3         Snoop Dogg       2693
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       1878
# 1       LeBron James       2669
# 2         Snoop Dogg       2694
# 3  Sabrina Carpenter       2759
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       1925
# 1       LeBron James       2629
# 2         Snoop Dogg       2693
# 3  Sabrina Carpenter       2753
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       1929
# 1       LeBron James       2637
# 2         Snoop Dogg       2679
# 3  Sabrina Carpenter       2755
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2008
# 1       LeBron James       2609
# 2         Snoop Dogg       2666
# 3  Sabrina Carpenter       2717
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2094
# 1       LeBron James       2610
# 2         Snoop Dogg       2658
# 3  Sabrina Carpenter       2638
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2095
# 1       LeBron James       2607
# 2         Snoop Dogg       2654
# 3  Sabrina Carpenter       2644
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2114
# 1       LeBron James       2588
# 2         Snoop Dogg       2666
# 3  Sabrina Carpenter       2632
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2185
# 1       LeBron James       2593
# 2         Snoop Dogg       2611
# 3  Sabrina Carpenter       2611
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2236
# 1       LeBron James       2587
# 2         Snoop Dogg       2581
# 3  Sabrina Carpenter       2596
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2279
# 1       LeBron James       2595
# 2         Snoop Dogg       2549
# 3  Sabrina Carpenter       2577
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2369
# 1       LeBron James       2580
# 2         Snoop Dogg       2533
# 3  Sabrina Carpenter       2518
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2428
# 1       LeBron James       2584
# 2         Snoop Dogg       2504
# 3  Sabrina Carpenter       2484
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2444
# 1       LeBron James       2574
# 2         Snoop Dogg       2512
# 3  Sabrina Carpenter       2470
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2522
# 1         Snoop Dogg       2598
# 2  Sabrina Carpenter       2574
# 3       LeBron James       2306
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2650
# 1         Snoop Dogg       2734
# 2  Sabrina Carpenter       2699
# 3       LeBron James       1917
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# ...
# 0         Tony Stark       2244
# 1         Snoop Dogg       2385
# 2  Sabrina Carpenter       2690
# 3       LeBron James       2681
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2300
# 1         Snoop Dogg       2369
# 2  Sabrina Carpenter       2669
# 3       LeBron James       2662
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2394
# 1         Snoop Dogg       2386
# 2  Sabrina Carpenter       2604
# 3       LeBron James       2616
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2418
# 1         Snoop Dogg       2425
# 2  Sabrina Carpenter       2547
# 3       LeBron James       2610
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2444
# 1         Snoop Dogg       2482
# 2  Sabrina Carpenter       2502
# 3       LeBron James       2572
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2452
# 1         Snoop Dogg       2490
# 2  Sabrina Carpenter       2507
# 3       LeBron James       2551
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2467
# 1         Snoop Dogg       2492
# 2  Sabrina Carpenter       2502
# 3       LeBron James       2539
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2467
# 1         Snoop Dogg       2492
# 2  Sabrina Carpenter       2502
# 3       LeBron James       2539
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2585
# 1         Snoop Dogg       2182
# 2  Sabrina Carpenter       2603
# 3       LeBron James       2630
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2664
# 1         Snoop Dogg       2276
# 2  Sabrina Carpenter       2689
# 3       LeBron James       2371
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2665
# 1         Snoop Dogg       2277
# 2  Sabrina Carpenter       2687
# 3       LeBron James       2371
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2840
# 1         Snoop Dogg       2436
# 2  Sabrina Carpenter       2171
# 3       LeBron James       2553
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2630
# 1         Snoop Dogg       2501
# 2  Sabrina Carpenter       2235
# 3       LeBron James       2634
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       1976
# 1         Snoop Dogg       2719
# 2  Sabrina Carpenter       2446
# 3       LeBron James       2859
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2057
# 1         Snoop Dogg       2786
# 2  Sabrina Carpenter       2213
# 3       LeBron James       2944
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2057
# 1         Snoop Dogg       2786
# 2  Sabrina Carpenter       2213
# 3       LeBron James       2944
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2219
# 1         Snoop Dogg       2968
# 2  Sabrina Carpenter       2376
# 3       LeBron James       2437
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2373
# 1         Snoop Dogg       2971
# 2         Tony Stark       2214
# 3       LeBron James       2442
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2392
# 1         Snoop Dogg       2895
# 2         Tony Stark       2245
# 3       LeBron James       2468
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2418
# 1         Snoop Dogg       2849
# 2         Tony Stark       2269
# 3       LeBron James       2464
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2482
# 1         Snoop Dogg       2915
# 2         Tony Stark       2064
# 3       LeBron James       2539
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2530
# 1         Snoop Dogg       2946
# 2         Tony Stark       2106
# 3       LeBron James       2418
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2567
# 1         Snoop Dogg       2990
# 2         Tony Stark       2136
# 3       LeBron James       2307
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2568
# 1         Snoop Dogg       2937
# 2         Tony Stark       2151
# 3       LeBron James       2344
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2560
# 1         Snoop Dogg       2923
# 2         Tony Stark       2162
# 3       LeBron James       2355
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2615
# 1         Snoop Dogg       3001
# 2         Tony Stark       2221
# 3       LeBron James       2163
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2620
# 1         Snoop Dogg       2969
# 2         Tony Stark       2234
# 3       LeBron James       2177
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2580
# 1         Snoop Dogg       2924
# 2         Tony Stark       2265
# 3       LeBron James       2231
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0  Sabrina Carpenter       2562
# 1         Snoop Dogg       2920
# 2         Tony Stark       2275
# 3       LeBron James       2243
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2288
# 1         Snoop Dogg       2900
# 2  Sabrina Carpenter       2551
# 3       LeBron James       2261
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2298
# 1         Snoop Dogg       2875
# 2  Sabrina Carpenter       2558
# 3       LeBron James       2269
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2481
# 1         Snoop Dogg       2320
# 2  Sabrina Carpenter       2747
# 3       LeBron James       2452
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2581
# 1         Snoop Dogg       2014
# 2  Sabrina Carpenter       2850
# 3       LeBron James       2555
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2725
# 1         Snoop Dogg       1596
# 2  Sabrina Carpenter       2984
# 3       LeBron James       2695
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2725
# 1  Sabrina Carpenter       2982
# 2         Snoop Dogg       1600
# 3       LeBron James       2693
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2686
# 1  Sabrina Carpenter       2938
# 2         Snoop Dogg       1737
# 3       LeBron James       2639
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2686
# 1  Sabrina Carpenter       2938
# 2         Snoop Dogg       1737
# 3       LeBron James       2639
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2274
# 1  Sabrina Carpenter       3065
# 2         Snoop Dogg       1873
# 3       LeBron James       2788
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2286
# 1  Sabrina Carpenter       3045
# 2         Snoop Dogg       1906
# 3       LeBron James       2763
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2256
# 1  Sabrina Carpenter       2979
# 2         Snoop Dogg       2019
# 3       LeBron James       2746
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2257
# 1  Sabrina Carpenter       2980
# 2         Snoop Dogg       2020
# 3       LeBron James       2743
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2292
# 1  Sabrina Carpenter       2929
# 2         Snoop Dogg       2078
# 3       LeBron James       2701
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Tony Stark       2295
# 1  Sabrina Carpenter       2916
# 2         Snoop Dogg       2117
# 3       LeBron James       2672
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2660
# 1         Tony Stark       2297
# 2  Sabrina Carpenter       2903
# 3         Snoop Dogg       2140
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2633
# 1         Tony Stark       2314
# 2  Sabrina Carpenter       2854
# 3         Snoop Dogg       2199
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2567
# 1         Tony Stark       2330
# 2  Sabrina Carpenter       2834
# 3         Snoop Dogg       2269
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2536
# 1         Tony Stark       2352
# 2  Sabrina Carpenter       2797
# 3         Snoop Dogg       2315
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2560
# 1         Tony Stark       2350
# 2  Sabrina Carpenter       2759
# 3         Snoop Dogg       2331
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2519
# 1         Tony Stark       2367
# 2  Sabrina Carpenter       2701
# 3         Snoop Dogg       2413
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2517
# 1         Tony Stark       2402
# 2  Sabrina Carpenter       2623
# 3         Snoop Dogg       2458
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0       LeBron James       2523
# 1         Tony Stark       2402
# 2  Sabrina Carpenter       2621
# 3         Snoop Dogg       2454
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2471
# 1         Tony Stark       2421
# 2  Sabrina Carpenter       2613
# 3       LeBron James       2495
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2455
# 1         Tony Stark       2409
# 2  Sabrina Carpenter       2595
# 3       LeBron James       2541
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2460
# 1         Tony Stark       2416
# 2  Sabrina Carpenter       2597
# 3       LeBron James       2527
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2546
# 1         Tony Stark       2493
# 2  Sabrina Carpenter       2682
# 3       LeBron James       2279
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2564
# 1         Tony Stark       2508
# 2  Sabrina Carpenter       2666
# 3       LeBron James       2262
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2564
# 1         Tony Stark       2519
# 2  Sabrina Carpenter       2650
# 3       LeBron James       2267
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2518
# 1         Tony Stark       2525
# 2  Sabrina Carpenter       2670
# 3       LeBron James       2287
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2500
# 1         Tony Stark       2504
# 2  Sabrina Carpenter       2690
# 3       LeBron James       2306
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2583
# 1         Tony Stark       2597
# 2  Sabrina Carpenter       2442
# 3       LeBron James       2378
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2790
# 1         Tony Stark       2759
# 2  Sabrina Carpenter       1889
# 3       LeBron James       2562
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2769
# 1         Tony Stark       2760
# 2  Sabrina Carpenter       1925
# 3       LeBron James       2546
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2734
# 1         Tony Stark       2768
# 2  Sabrina Carpenter       1955
# 3       LeBron James       2543
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2716
# 1  Sabrina Carpenter       1972
# 2         Tony Stark       2774
# 3       LeBron James       2538
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2694
# 1  Sabrina Carpenter       2013
# 2         Tony Stark       2754
# 3       LeBron James       2539
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2645
# 1  Sabrina Carpenter       2058
# 2         Tony Stark       2723
# 3       LeBron James       2574
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2613
# 1  Sabrina Carpenter       2138
# 2         Tony Stark       2643
# 3       LeBron James       2606
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2587
# 1  Sabrina Carpenter       2207
# 2         Tony Stark       2625
# 3       LeBron James       2581
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2592
# 1  Sabrina Carpenter       2296
# 2         Tony Stark       2556
# 3       LeBron James       2556
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2573
# 1  Sabrina Carpenter       2351
# 2         Tony Stark       2543
# 3       LeBron James       2533
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2552
# 1  Sabrina Carpenter       2416
# 2         Tony Stark       2517
# 3       LeBron James       2515
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2606
# 1  Sabrina Carpenter       2471
# 2         Tony Stark       2355
# 3       LeBron James       2568
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2626
# 1  Sabrina Carpenter       2494
# 2         Tony Stark       2290
# 3       LeBron James       2590
# Graph updated successfully.
# Data retrieved successfully:     current_favorite  fan_count
# 0         Snoop Dogg       2636
# 1       LeBron James       2583
# 2  Sabrina Carpenter       2489
# 3         Tony Stark       2292
# Graph updated successfully.

# %% [raw]
# # Function to retrieve the fan count for each celebrity
# def get_fan_counts():
#     connection = create_connection()  # Assuming create_connection() is defined elsewhere
#     query = """
#     SELECT current_favorite, COUNT(*) as fan_count
#     FROM user_dynamic_preferences
#     GROUP BY current_favorite;
#     """
#     # Use the raw MySQL connection to fetch the data
#     df = pd.read_sql(query, con=connection)
#     connection.close()
#     return df
#
# # Initialize Dash app
# app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])
#
# # Initialize layout with an empty figure and an interval component
# app.layout = html.Div([
#     html.H1("Real-Time Fan Count of Celebrities"),
#     dcc.Graph(id='live-update-graph'),
#     dcc.Interval(
#         id='interval-component',
#         interval=300,  # in milliseconds (0.3 seconds)
#         n_intervals=0
#     )
# ])
#
# # Initialize data storage
# fan_counts_data = {celebrity: [] for celebrity in ['Sabrina Carpenter', 'Snoop Dogg', 'Tony Stark', 'LeBron James']}
# time_data = []
#
# # Callback to update the graph
# @app.callback(
#     Output('live-update-graph', 'figure'),
#     Input('interval-component', 'n_intervals')
# )
# def update_graph(n):
#     global time_data, fan_counts_data
#
#     # Fetch the latest fan counts
#     df = get_fan_counts()
#
#     # Append the current timestamp
#     current_time = time.time()
#     time_data.append(current_time - time_data[0] if time_data else 0)
#
#     # Update the fan counts data
#     for celebrity in fan_counts_data.keys():
#         fan_count = df[df['current_favorite'] == celebrity]['fan_count'].sum() if not df[df['current_favorite'] == celebrity].empty else 0
#         fan_counts_data[celebrity].append(fan_count)
#
#     # Create traces for each celebrity
#     fig = go.Figure()
#     for celebrity, fan_counts in fan_counts_data.items():
#         fig.add_trace(go.Scatter(
#             x=time_data,
#             y=fan_counts,
#             mode='lines+markers',
#             name=celebrity
#         ))
#
#     # Set graph layout properties
#     fig.update_layout(
#         xaxis_title='Time (seconds)',
#         yaxis_title='Number of Fans',
#         title='Real-Time Fan Count of Celebrities',
#         xaxis=dict(range=[max(time_data) - 100, max(time_data)]),
#         yaxis=dict(range=[0, 1000])
#     )
#
#     return fig
#
# if __name__ == '__main__':
#     app.run_server(debug=True)
